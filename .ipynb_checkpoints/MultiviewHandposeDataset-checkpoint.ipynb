# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/My\ Drive/Rovit\ Dataset.zip

# %% [markdown]
# <h2><b>Data Preprocessing Part</b></h2>

# %%
import os
import re
import pickle
import numpy as np
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# %%
def joint_reader():
  """
  Read 2D Joints information.
  """
  joint_dict = {}
  data_dir = "/content/Rovit Dataset/projections_2d/data_1"

  with os.scandir(data_dir) as entries:
    for entry in entries:
      with open(os.path.join(data_dir, entry.name), "r") as f:
        joint_ar = np.zeros((0, 2))
        for line in f:
          _, x, y = line.split()
          joint_coordinate = np.array([[float(x), float(y)]])
          joint_ar = np.vstack((joint_ar, joint_coordinate))
        joint_dict["".join(re.findall("[0-9]+[_]*", entry.name))] = joint_ar

  return joint_dict

# %%
def bbox_reader():
  """
  Read bounding box information.
  """
  bounding_box_dict = {}
  data_dir = "/content/Rovit Dataset/bounding_boxes/data_1"

  with os.scandir(data_dir) as entries:
    for entry in entries:
      with open(os.path.join(data_dir, entry.name), "r") as f:
        bounding_box_dict["".join(re.findall("[0-9]+[_]*", entry.name))] = dict()
        for line in f:
          d_key, d_value = line.split()
          bounding_box_dict["".join(re.findall("[0-9]+[_]*", entry.name))][d_key] = np.array([[int(d_value)]])

  return bounding_box_dict

# %%
def image_reader():
  """
  Read image files.
  """
  image_dict = {}
  data_dir = "/content/Rovit Dataset/annotated_frames/data_1"

  with os.scandir(data_dir) as entries:
    for entry in entries:
      with open(os.path.join(data_dir, entry.name), "r") as f:
        if entry.name.endswith(".jpg"):
          image_dict["".join(re.findall("[0-9]+[_]*", entry.name))] = Image.open(os.path.join(data_dir, entry.name))
  
  return image_dict

# %%
def pickle_creator():
  """
  Create a pickled dataset.
  """
  pickle_dict = {"images": image_reader(),
                 "joints": joint_reader(),
                 "bounding_boxes": bbox_reader()}

  with open("dataset.pickle", "wb") as dataset:
    pickle.dump(pickle_dict, dataset)

# %%
pickle_creator()

# %%
# Read the data into a dictionary called dataset
dataset = {}
with open("dataset.pickle", "rb") as f:
  dataset = pickle.load(f, encoding="bytes")

# %%
def crop_images():
  """
  Crop the images in the dataset with the given bounding box information.
  Also, keep track of the greatest heights and widths so we can resize the
  images later.
  """
  max_width, max_height = 0, 0
  cropped_dict = dict()
  for im_name, im in dataset["images"].items():
    cropped_dict[im_name] = im.crop(
        (dataset["bounding_boxes"][im_name]["LEFT"][0, 0],
         dataset["bounding_boxes"][im_name]["TOP"][0, 0],
         dataset["bounding_boxes"][im_name]["RIGHT"][0, 0],
         dataset["bounding_boxes"][im_name]["BOTTOM"][0, 0])
        )
    
    if cropped_dict[im_name].width > max_width:
      max_width = cropped_dict[im_name].width
    if cropped_dict[im_name].height > max_height:
      max_height = cropped_dict[im_name].height

  return cropped_dict, max_width, max_height

# %%
cropped_images, max_width, max_height = crop_images()

# %%
padded_images = dict()

for im_name, im in cropped_images.items():
  h_pad = 400 - cropped_images[im_name].height
  w_pad = 400 - cropped_images[im_name].width
  # w_pad // 2 -> Left padding
  # h_pad // 2 -> Top padding
  padding = (w_pad // 2, h_pad // 2, w_pad - (w_pad // 2), h_pad - (h_pad // 2))
  padded_images[im_name] = ImageOps.expand(cropped_images[im_name], padding)

# %%
padded_images["623_3"] # An example image
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F508BF85908>

# %%
# Rearrange joint coordinates

for im_name, joints in dataset["joints"].items():
  bounding_box = dataset["bounding_boxes"][im_name]
  h_pad = 400 - cropped_images[im_name].height
  w_pad = 400 - cropped_images[im_name].width
  subt = np.array([[bounding_box["LEFT"][0, 0] - (w_pad // 2), bounding_box["TOP"][0, 0] - (h_pad // 2)]])
  joints -= subt

# %%
def show_joints(image_name, landmarks=None):

    """
    Show image with joints marked. Code adapted from https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
    """

    image = padded_images[image_name]
    plt.imshow(image, aspect="auto")
    if landmarks is None:
      landmarks = dataset["joints"][image_name]
    plt.scatter(landmarks[:, 0], landmarks[:, 1], s=10, marker='.', c='r')
    plt.pause(0.001)

# %%
plt.figure()
show_joints("707_4")
plt.show()

# %% [markdown]
# <h2><b>Deep Learning</b></h2>

# %%
import torch
import torch.nn as nn
import torchvision
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import datasets, models, transforms, utils
from torch.utils.data import Dataset, DataLoader
import torch.utils.data

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class MultiViewHandposeDataset(Dataset):

  def __init__(self, padded_images, joints):
    self.joints = joints
    self.images = list()
    for im_name, im in padded_images.items():
      self.images.append((im_name, torch.tensor(np.asarray(im), dtype=torch.double).permute(2, 0, 1)))
    
  def __len__(self):
    return len(self.images)

  def __getitem__(self, idx):
    image = self.images[idx][1]
    joints = self.joints[self.images[idx][0]]

    sample = {"image_name": self.images[idx][0],
              "image": image,
              "joints": joints.flatten()}

    return sample

# %%
hand_dataset = MultiViewHandposeDataset(padded_images, dataset["joints"])

# %%
num_epochs = 100
num_outputs = 42
batch_size = 16
learning_rate = 0.001
validation_split = .1

# %%
train_dataset, validation_dataset = torch.utils.data.random_split(hand_dataset,
                                                                  (int(len(hand_dataset) * validation_split),
                                                                  len(hand_dataset) - int(len(hand_dataset) * validation_split)))

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
for i_batch, sample_batched in enumerate(train_loader):
    print(i_batch, sample_batched['image'].size(),
          sample_batched['joints'].size())
    
    break
# Out:
# 0 torch.Size([16, 3, 400, 400]) torch.Size([16, 42])

# %%
model = torchvision.models.resnet18(pretrained=True).float()

# %%
model.fc = nn.Linear(in_features=512, out_features=42, bias=True)

# %%
model = model.to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
total_step = len(train_loader)

for epoch in range(num_epochs):
    for i, sample in enumerate(train_loader):
        images = sample["image"].to(device)
        labels = sample["joints"].to(device)
        
        # Forward pass
        outputs = model(images.float())
        loss = criterion(outputs.double(), labels.double())
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 2 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
# Out:
# Epoch [1/100], Step [2/18], Loss: 45.9713
# Epoch [1/100], Step [4/18], Loss: 48.6417
# Epoch [1/100], Step [6/18], Loss: 48.8694
# Epoch [1/100], Step [8/18], Loss: 38.7661
# Epoch [1/100], Step [10/18], Loss: 76.0336
# Epoch [1/100], Step [12/18], Loss: 55.3524
# Epoch [1/100], Step [14/18], Loss: 50.6954
# Epoch [1/100], Step [16/18], Loss: 40.4685
# Epoch [1/100], Step [18/18], Loss: 59.5140
# Epoch [2/100], Step [2/18], Loss: 61.0671
# Epoch [2/100], Step [4/18], Loss: 58.8370
# Epoch [2/100], Step [6/18], Loss: 107.5934
# Epoch [2/100], Step [8/18], Loss: 45.9634
# Epoch [2/100], Step [10/18], Loss: 48.8428
# Epoch [2/100], Step [12/18], Loss: 34.9133
# Epoch [2/100], Step [14/18], Loss: 43.5085
# Epoch [2/100], Step [16/18], Loss: 59.2369
# Epoch [2/100], Step [18/18], Loss: 70.4211
# Epoch [3/100], Step [2/18], Loss: 41.5292
# Epoch [3/100], Step [4/18], Loss: 89.2355
# Epoch [3/100], Step [6/18], Loss: 71.1507
# Epoch [3/100], Step [8/18], Loss: 49.2028
# Epoch [3/100], Step [10/18], Loss: 41.9118
# Epoch [3/100], Step [12/18], Loss: 63.5899
# Epoch [3/100], Step [14/18], Loss: 42.5960
# Epoch [3/100], Step [16/18], Loss: 51.5046
# Epoch [3/100], Step [18/18], Loss: 60.3997
# Epoch [4/100], Step [2/18], Loss: 80.0831
# Epoch [4/100], Step [4/18], Loss: 47.8276
# Epoch [4/100], Step [6/18], Loss: 58.2345
# Epoch [4/100], Step [8/18], Loss: 42.1624
# Epoch [4/100], Step [10/18], Loss: 68.2009
# Epoch [4/100], Step [12/18], Loss: 62.6189
# Epoch [4/100], Step [14/18], Loss: 48.6120
# Epoch [4/100], Step [16/18], Loss: 71.9504
# Epoch [4/100], Step [18/18], Loss: 49.7686
# Epoch [5/100], Step [2/18], Loss: 45.7807
# Epoch [5/100], Step [4/18], Loss: 57.2603
# Epoch [5/100], Step [6/18], Loss: 50.4228
# Epoch [5/100], Step [8/18], Loss: 44.4607
# Epoch [5/100], Step [10/18], Loss: 84.3068
# Epoch [5/100], Step [12/18], Loss: 103.1512
# Epoch [5/100], Step [14/18], Loss: 55.0728
# Epoch [5/100], Step [16/18], Loss: 45.7014
# Epoch [5/100], Step [18/18], Loss: 57.8300
# Epoch [6/100], Step [2/18], Loss: 84.5358
# Epoch [6/100], Step [4/18], Loss: 52.2081
# Epoch [6/100], Step [6/18], Loss: 73.9641
# Epoch [6/100], Step [8/18], Loss: 34.0021
# Epoch [6/100], Step [10/18], Loss: 51.3186
# Epoch [6/100], Step [12/18], Loss: 56.5516
# Epoch [6/100], Step [14/18], Loss: 81.7075
# Epoch [6/100], Step [16/18], Loss: 49.6812
# Epoch [6/100], Step [18/18], Loss: 47.4836
# Epoch [7/100], Step [2/18], Loss: 61.4644
# Epoch [7/100], Step [4/18], Loss: 71.4040
# Epoch [7/100], Step [6/18], Loss: 55.9968
# Epoch [7/100], Step [8/18], Loss: 61.9353
# Epoch [7/100], Step [10/18], Loss: 54.1201
# Epoch [7/100], Step [12/18], Loss: 103.9611
# Epoch [7/100], Step [14/18], Loss: 79.8212
# Epoch [7/100], Step [16/18], Loss: 49.3485
# Epoch [7/100], Step [18/18], Loss: 152.3407
# Epoch [8/100], Step [2/18], Loss: 235.5874
# Epoch [8/100], Step [4/18], Loss: 80.7145
# Epoch [8/100], Step [6/18], Loss: 214.8018
# Epoch [8/100], Step [8/18], Loss: 184.6134
# Epoch [8/100], Step [10/18], Loss: 259.7122
# Epoch [8/100], Step [12/18], Loss: 239.0974
# Epoch [8/100], Step [14/18], Loss: 203.8379
# Epoch [8/100], Step [16/18], Loss: 217.9345
# Epoch [8/100], Step [18/18], Loss: 147.2772
# Epoch [9/100], Step [2/18], Loss: 329.5754
# Epoch [9/100], Step [4/18], Loss: 152.2292
# Epoch [9/100], Step [6/18], Loss: 138.3996
# Epoch [9/100], Step [8/18], Loss: 148.8850
# Epoch [9/100], Step [10/18], Loss: 103.7833
# Epoch [9/100], Step [12/18], Loss: 121.5750
# Epoch [9/100], Step [14/18], Loss: 149.4309
# Epoch [9/100], Step [16/18], Loss: 140.6707
# Epoch [9/100], Step [18/18], Loss: 75.9910
# Epoch [10/100], Step [2/18], Loss: 169.4096
# Epoch [10/100], Step [4/18], Loss: 97.5031
# Epoch [10/100], Step [6/18], Loss: 167.9889
# Epoch [10/100], Step [8/18], Loss: 58.1034
# Epoch [10/100], Step [10/18], Loss: 121.4906
# Epoch [10/100], Step [12/18], Loss: 51.6693
# Epoch [10/100], Step [14/18], Loss: 79.7147
# Epoch [10/100], Step [16/18], Loss: 122.2701
# Epoch [10/100], Step [18/18], Loss: 115.0394
# Epoch [11/100], Step [2/18], Loss: 77.9518
# Epoch [11/100], Step [4/18], Loss: 95.0149
# Epoch [11/100], Step [6/18], Loss: 71.6045
# Epoch [11/100], Step [8/18], Loss: 85.6921
# Epoch [11/100], Step [10/18], Loss: 72.0688
# Epoch [11/100], Step [12/18], Loss: 63.1202
# Epoch [11/100], Step [14/18], Loss: 49.8651
# Epoch [11/100], Step [16/18], Loss: 63.0163
# Epoch [11/100], Step [18/18], Loss: 74.3168
# Epoch [12/100], Step [2/18], Loss: 63.9155
# Epoch [12/100], Step [4/18], Loss: 76.7351
# Epoch [12/100], Step [6/18], Loss: 51.6413
# Epoch [12/100], Step [8/18], Loss: 64.9321
# Epoch [12/100], Step [10/18], Loss: 77.2283
# Epoch [12/100], Step [12/18], Loss: 104.1029
# Epoch [12/100], Step [14/18], Loss: 50.0738
# Epoch [12/100], Step [16/18], Loss: 59.2157
# Epoch [12/100], Step [18/18], Loss: 48.0454
# Epoch [13/100], Step [2/18], Loss: 52.4754
# Epoch [13/100], Step [4/18], Loss: 52.6144
# Epoch [13/100], Step [6/18], Loss: 54.0530
# Epoch [13/100], Step [8/18], Loss: 47.9336
# Epoch [13/100], Step [10/18], Loss: 51.4417
# Epoch [13/100], Step [12/18], Loss: 98.8526
# Epoch [13/100], Step [14/18], Loss: 60.9428
# Epoch [13/100], Step [16/18], Loss: 62.7350
# Epoch [13/100], Step [18/18], Loss: 74.0172
# Epoch [14/100], Step [2/18], Loss: 46.5181
# Epoch [14/100], Step [4/18], Loss: 45.3119
# Epoch [14/100], Step [6/18], Loss: 53.9242
# Epoch [14/100], Step [8/18], Loss: 55.8575
# Epoch [14/100], Step [10/18], Loss: 30.0441
# Epoch [14/100], Step [12/18], Loss: 52.6816
# Epoch [14/100], Step [14/18], Loss: 43.3670
# Epoch [14/100], Step [16/18], Loss: 45.1516
# Epoch [14/100], Step [18/18], Loss: 67.0679
# Epoch [15/100], Step [2/18], Loss: 28.1579
# Epoch [15/100], Step [4/18], Loss: 52.6461
# Epoch [15/100], Step [6/18], Loss: 43.9200
# Epoch [15/100], Step [8/18], Loss: 49.9681
# Epoch [15/100], Step [10/18], Loss: 71.2042
# Epoch [15/100], Step [12/18], Loss: 55.4231
# Epoch [15/100], Step [14/18], Loss: 55.7992
# Epoch [15/100], Step [16/18], Loss: 34.8014
# Epoch [15/100], Step [18/18], Loss: 44.2519
# Epoch [16/100], Step [2/18], Loss: 42.6458
# Epoch [16/100], Step [4/18], Loss: 44.4545
# Epoch [16/100], Step [6/18], Loss: 63.8699
# Epoch [16/100], Step [8/18], Loss: 26.2746
# Epoch [16/100], Step [10/18], Loss: 56.4281
# Epoch [16/100], Step [12/18], Loss: 66.0951
# Epoch [16/100], Step [14/18], Loss: 29.8415
# Epoch [16/100], Step [16/18], Loss: 56.5245
# Epoch [16/100], Step [18/18], Loss: 58.0861
# Epoch [17/100], Step [2/18], Loss: 34.7585
# Epoch [17/100], Step [4/18], Loss: 48.4239
# Epoch [17/100], Step [6/18], Loss: 39.8937
# Epoch [17/100], Step [8/18], Loss: 45.1832
# Epoch [17/100], Step [10/18], Loss: 42.3926
# Epoch [17/100], Step [12/18], Loss: 61.4282
# Epoch [17/100], Step [14/18], Loss: 41.3133
# Epoch [17/100], Step [16/18], Loss: 46.1285
# Epoch [17/100], Step [18/18], Loss: 51.9655
# Epoch [18/100], Step [2/18], Loss: 30.1243
# Epoch [18/100], Step [4/18], Loss: 36.9305
# Epoch [18/100], Step [6/18], Loss: 76.3849
# Epoch [18/100], Step [8/18], Loss: 31.8759
# Epoch [18/100], Step [10/18], Loss: 63.2689
# Epoch [18/100], Step [12/18], Loss: 44.0276
# Epoch [18/100], Step [14/18], Loss: 55.6103
# Epoch [18/100], Step [16/18], Loss: 43.9153
# Epoch [18/100], Step [18/18], Loss: 58.2807
# Epoch [19/100], Step [2/18], Loss: 52.1110
# Epoch [19/100], Step [4/18], Loss: 49.9531
# Epoch [19/100], Step [6/18], Loss: 44.0162
# Epoch [19/100], Step [8/18], Loss: 31.6893
# Epoch [19/100], Step [10/18], Loss: 41.9209
# Epoch [19/100], Step [12/18], Loss: 37.5977
# Epoch [19/100], Step [14/18], Loss: 48.0365
# Epoch [19/100], Step [16/18], Loss: 51.9738
# Epoch [19/100], Step [18/18], Loss: 45.9991
# Epoch [20/100], Step [2/18], Loss: 37.9322
# Epoch [20/100], Step [4/18], Loss: 54.6433
# Epoch [20/100], Step [6/18], Loss: 34.5654
# Epoch [20/100], Step [8/18], Loss: 53.2145
# Epoch [20/100], Step [10/18], Loss: 41.8399
# Epoch [20/100], Step [12/18], Loss: 39.2244
# Epoch [20/100], Step [14/18], Loss: 59.4874
# Epoch [20/100], Step [16/18], Loss: 56.2632
# Epoch [20/100], Step [18/18], Loss: 61.8991
# Epoch [21/100], Step [2/18], Loss: 37.9594
# Epoch [21/100], Step [4/18], Loss: 45.0101
# Epoch [21/100], Step [6/18], Loss: 41.5369
# Epoch [21/100], Step [8/18], Loss: 56.2029
# Epoch [21/100], Step [10/18], Loss: 30.3014
# Epoch [21/100], Step [12/18], Loss: 35.4264
# Epoch [21/100], Step [14/18], Loss: 30.5728
# Epoch [21/100], Step [16/18], Loss: 34.9211
# Epoch [21/100], Step [18/18], Loss: 70.9766
# Epoch [22/100], Step [2/18], Loss: 39.5210
# Epoch [22/100], Step [4/18], Loss: 35.4970
# Epoch [22/100], Step [6/18], Loss: 31.7950
# Epoch [22/100], Step [8/18], Loss: 40.5144
# Epoch [22/100], Step [10/18], Loss: 47.8028
# Epoch [22/100], Step [12/18], Loss: 40.4984
# Epoch [22/100], Step [14/18], Loss: 76.3853
# Epoch [22/100], Step [16/18], Loss: 45.5001
# Epoch [22/100], Step [18/18], Loss: 50.6348
# Epoch [23/100], Step [2/18], Loss: 28.3237
# Epoch [23/100], Step [4/18], Loss: 29.9072
# Epoch [23/100], Step [6/18], Loss: 32.3515
# Epoch [23/100], Step [8/18], Loss: 46.8200
# Epoch [23/100], Step [10/18], Loss: 66.1852
# Epoch [23/100], Step [12/18], Loss: 31.5170
# Epoch [23/100], Step [14/18], Loss: 50.5008
# Epoch [23/100], Step [16/18], Loss: 41.3042
# Epoch [23/100], Step [18/18], Loss: 46.7702
# Epoch [24/100], Step [2/18], Loss: 49.1524
# Epoch [24/100], Step [4/18], Loss: 80.5794
# Epoch [24/100], Step [6/18], Loss: 44.3274
# Epoch [24/100], Step [8/18], Loss: 56.0650
# Epoch [24/100], Step [10/18], Loss: 29.7982
# Epoch [24/100], Step [12/18], Loss: 35.3869
# Epoch [24/100], Step [14/18], Loss: 69.2725
# Epoch [24/100], Step [16/18], Loss: 42.4706
# Epoch [24/100], Step [18/18], Loss: 56.8040
# Epoch [25/100], Step [2/18], Loss: 33.0869
# Epoch [25/100], Step [4/18], Loss: 37.9165
# Epoch [25/100], Step [6/18], Loss: 48.1396
# Epoch [25/100], Step [8/18], Loss: 39.9631
# Epoch [25/100], Step [10/18], Loss: 35.5444
# Epoch [25/100], Step [12/18], Loss: 34.9384
# Epoch [25/100], Step [14/18], Loss: 54.0222
# Epoch [25/100], Step [16/18], Loss: 30.7700
# Epoch [25/100], Step [18/18], Loss: 36.9351
# Epoch [26/100], Step [2/18], Loss: 61.9384
# Epoch [26/100], Step [4/18], Loss: 45.7315
# Epoch [26/100], Step [6/18], Loss: 31.3658
# Epoch [26/100], Step [8/18], Loss: 40.1273
# Epoch [26/100], Step [10/18], Loss: 38.6957
# Epoch [26/100], Step [12/18], Loss: 48.3845
# Epoch [26/100], Step [14/18], Loss: 27.0053
# Epoch [26/100], Step [16/18], Loss: 57.6429
# Epoch [26/100], Step [18/18], Loss: 48.5356
# Epoch [27/100], Step [2/18], Loss: 46.8323
# Epoch [27/100], Step [4/18], Loss: 26.3853
# Epoch [27/100], Step [6/18], Loss: 41.2893
# Epoch [27/100], Step [8/18], Loss: 42.0596
# Epoch [27/100], Step [10/18], Loss: 46.6823
# Epoch [27/100], Step [12/18], Loss: 50.9099
# Epoch [27/100], Step [14/18], Loss: 34.4358
# Epoch [27/100], Step [16/18], Loss: 46.0333
# Epoch [27/100], Step [18/18], Loss: 45.6962
# Epoch [28/100], Step [2/18], Loss: 27.9335
# Epoch [28/100], Step [4/18], Loss: 39.4007
# Epoch [28/100], Step [6/18], Loss: 41.3663
# Epoch [28/100], Step [8/18], Loss: 48.2471
# Epoch [28/100], Step [10/18], Loss: 60.7982
# Epoch [28/100], Step [12/18], Loss: 70.8379
# Epoch [28/100], Step [14/18], Loss: 51.6931
# Epoch [28/100], Step [16/18], Loss: 33.5446
# Epoch [28/100], Step [18/18], Loss: 67.9135
# Epoch [29/100], Step [2/18], Loss: 39.0826
# Epoch [29/100], Step [4/18], Loss: 29.3565
# Epoch [29/100], Step [6/18], Loss: 41.3324
# Epoch [29/100], Step [8/18], Loss: 53.1497
# Epoch [29/100], Step [10/18], Loss: 39.2643
# Epoch [29/100], Step [12/18], Loss: 41.8807
# Epoch [29/100], Step [14/18], Loss: 40.0218
# Epoch [29/100], Step [16/18], Loss: 57.5834
# Epoch [29/100], Step [18/18], Loss: 36.5224
# Epoch [30/100], Step [2/18], Loss: 45.5195
# Epoch [30/100], Step [4/18], Loss: 51.5549
# Epoch [30/100], Step [6/18], Loss: 49.5792
# Epoch [30/100], Step [8/18], Loss: 34.7077
# Epoch [30/100], Step [10/18], Loss: 34.6194
# Epoch [30/100], Step [12/18], Loss: 50.3350
# Epoch [30/100], Step [14/18], Loss: 40.6046
# Epoch [30/100], Step [16/18], Loss: 41.1351
# Epoch [30/100], Step [18/18], Loss: 48.6509
# Epoch [31/100], Step [2/18], Loss: 37.8921
# Epoch [31/100], Step [4/18], Loss: 46.2962
# Epoch [31/100], Step [6/18], Loss: 29.3165
# Epoch [31/100], Step [8/18], Loss: 27.6254
# Epoch [31/100], Step [10/18], Loss: 35.2162
# Epoch [31/100], Step [12/18], Loss: 45.5304
# Epoch [31/100], Step [14/18], Loss: 33.1975
# Epoch [31/100], Step [16/18], Loss: 37.0662
# Epoch [31/100], Step [18/18], Loss: 34.8931
# Epoch [32/100], Step [2/18], Loss: 42.3672
# Epoch [32/100], Step [4/18], Loss: 51.6965
# Epoch [32/100], Step [6/18], Loss: 37.0517
# Epoch [32/100], Step [8/18], Loss: 29.9543
# Epoch [32/100], Step [10/18], Loss: 50.8216
# Epoch [32/100], Step [12/18], Loss: 38.8698
# Epoch [32/100], Step [14/18], Loss: 28.0763
# Epoch [32/100], Step [16/18], Loss: 37.2551
# Epoch [32/100], Step [18/18], Loss: 62.5999
# Epoch [33/100], Step [2/18], Loss: 33.8900
# Epoch [33/100], Step [4/18], Loss: 42.4945
# Epoch [33/100], Step [6/18], Loss: 47.8599
# Epoch [33/100], Step [8/18], Loss: 35.0668
# Epoch [33/100], Step [10/18], Loss: 34.5893
# Epoch [33/100], Step [12/18], Loss: 50.8611
# Epoch [33/100], Step [14/18], Loss: 35.8807
# Epoch [33/100], Step [16/18], Loss: 35.7389
# Epoch [33/100], Step [18/18], Loss: 50.3171
# Epoch [34/100], Step [2/18], Loss: 28.7031
# Epoch [34/100], Step [4/18], Loss: 34.7068
# Epoch [34/100], Step [6/18], Loss: 32.2680
# Epoch [34/100], Step [8/18], Loss: 36.8003
# Epoch [34/100], Step [10/18], Loss: 36.1131
# Epoch [34/100], Step [12/18], Loss: 50.2030
# Epoch [34/100], Step [14/18], Loss: 59.3952
# Epoch [34/100], Step [16/18], Loss: 50.6470
# Epoch [34/100], Step [18/18], Loss: 34.8474
# Epoch [35/100], Step [2/18], Loss: 35.9107
# Epoch [35/100], Step [4/18], Loss: 28.6908
# Epoch [35/100], Step [6/18], Loss: 49.0629
# Epoch [35/100], Step [8/18], Loss: 55.3526
# Epoch [35/100], Step [10/18], Loss: 31.5387
# Epoch [35/100], Step [12/18], Loss: 42.8487
# Epoch [35/100], Step [14/18], Loss: 29.2644
# Epoch [35/100], Step [16/18], Loss: 31.5047
# Epoch [35/100], Step [18/18], Loss: 39.1921
# Epoch [36/100], Step [2/18], Loss: 38.4362
# Epoch [36/100], Step [4/18], Loss: 26.2809
# Epoch [36/100], Step [6/18], Loss: 38.9287
# Epoch [36/100], Step [8/18], Loss: 39.4000
# Epoch [36/100], Step [10/18], Loss: 26.8517
# Epoch [36/100], Step [12/18], Loss: 35.8259
# Epoch [36/100], Step [14/18], Loss: 45.8327
# Epoch [36/100], Step [16/18], Loss: 39.4399
# Epoch [36/100], Step [18/18], Loss: 35.1130
# Epoch [37/100], Step [2/18], Loss: 51.7043
# Epoch [37/100], Step [4/18], Loss: 40.8075
# Epoch [37/100], Step [6/18], Loss: 29.5856
# Epoch [37/100], Step [8/18], Loss: 34.0557
# Epoch [37/100], Step [10/18], Loss: 36.3679
# Epoch [37/100], Step [12/18], Loss: 33.7810
# Epoch [37/100], Step [14/18], Loss: 26.4641
# Epoch [37/100], Step [16/18], Loss: 29.8641
# Epoch [37/100], Step [18/18], Loss: 35.4981
# Epoch [38/100], Step [2/18], Loss: 33.3072
# Epoch [38/100], Step [4/18], Loss: 28.1731
# Epoch [38/100], Step [6/18], Loss: 39.6510
# Epoch [38/100], Step [8/18], Loss: 31.9631
# Epoch [38/100], Step [10/18], Loss: 30.2524
# Epoch [38/100], Step [12/18], Loss: 56.4821
# Epoch [38/100], Step [14/18], Loss: 41.8505
# Epoch [38/100], Step [16/18], Loss: 39.8152
# Epoch [38/100], Step [18/18], Loss: 52.5188
# Epoch [39/100], Step [2/18], Loss: 24.2814
# Epoch [39/100], Step [4/18], Loss: 20.3995
# Epoch [39/100], Step [6/18], Loss: 42.5554
# Epoch [39/100], Step [8/18], Loss: 50.7635
# Epoch [39/100], Step [10/18], Loss: 45.4929
# Epoch [39/100], Step [12/18], Loss: 40.7102
# Epoch [39/100], Step [14/18], Loss: 52.3786
# Epoch [39/100], Step [16/18], Loss: 32.4675
# Epoch [39/100], Step [18/18], Loss: 55.9782
# Epoch [40/100], Step [2/18], Loss: 37.4461
# Epoch [40/100], Step [4/18], Loss: 52.1389
# Epoch [40/100], Step [6/18], Loss: 51.4469
# Epoch [40/100], Step [8/18], Loss: 51.8121
# Epoch [40/100], Step [10/18], Loss: 37.6150
# Epoch [40/100], Step [12/18], Loss: 71.2000
# Epoch [40/100], Step [14/18], Loss: 57.3427
# Epoch [40/100], Step [16/18], Loss: 42.5888
# Epoch [40/100], Step [18/18], Loss: 57.8628
# Epoch [41/100], Step [2/18], Loss: 74.1078
# Epoch [41/100], Step [4/18], Loss: 64.5886
# Epoch [41/100], Step [6/18], Loss: 52.1535
# Epoch [41/100], Step [8/18], Loss: 51.3976
# Epoch [41/100], Step [10/18], Loss: 39.7938
# Epoch [41/100], Step [12/18], Loss: 49.8285
# Epoch [41/100], Step [14/18], Loss: 27.6376
# Epoch [41/100], Step [16/18], Loss: 44.0399
# Epoch [41/100], Step [18/18], Loss: 39.9544
# Epoch [42/100], Step [2/18], Loss: 45.8478
# Epoch [42/100], Step [4/18], Loss: 35.6267
# Epoch [42/100], Step [6/18], Loss: 35.4923
# Epoch [42/100], Step [8/18], Loss: 47.3739
# Epoch [42/100], Step [10/18], Loss: 37.5019
# Epoch [42/100], Step [12/18], Loss: 69.2672
# Epoch [42/100], Step [14/18], Loss: 49.0524
# Epoch [42/100], Step [16/18], Loss: 31.5262
# Epoch [42/100], Step [18/18], Loss: 36.9001
# Epoch [43/100], Step [2/18], Loss: 33.0112
# Epoch [43/100], Step [4/18], Loss: 44.6964
# Epoch [43/100], Step [6/18], Loss: 35.8431
# Epoch [43/100], Step [8/18], Loss: 39.2755
# Epoch [43/100], Step [10/18], Loss: 52.8535
# Epoch [43/100], Step [12/18], Loss: 44.7193
# Epoch [43/100], Step [14/18], Loss: 29.8785
# Epoch [43/100], Step [16/18], Loss: 31.3485
# Epoch [43/100], Step [18/18], Loss: 40.4668
# Epoch [44/100], Step [2/18], Loss: 40.1985
# Epoch [44/100], Step [4/18], Loss: 44.9440
# Epoch [44/100], Step [6/18], Loss: 30.7650
# Epoch [44/100], Step [8/18], Loss: 37.7755
# Epoch [44/100], Step [10/18], Loss: 42.6637
# Epoch [44/100], Step [12/18], Loss: 43.5694
# Epoch [44/100], Step [14/18], Loss: 35.5319
# Epoch [44/100], Step [16/18], Loss: 48.6972
# Epoch [44/100], Step [18/18], Loss: 37.2209
# Epoch [45/100], Step [2/18], Loss: 37.5479
# Epoch [45/100], Step [4/18], Loss: 45.2947
# Epoch [45/100], Step [6/18], Loss: 43.2011
# Epoch [45/100], Step [8/18], Loss: 33.0090
# Epoch [45/100], Step [10/18], Loss: 48.4636
# Epoch [45/100], Step [12/18], Loss: 51.7922
# Epoch [45/100], Step [14/18], Loss: 31.9253
# Epoch [45/100], Step [16/18], Loss: 33.4213
# Epoch [45/100], Step [18/18], Loss: 36.4510
# Epoch [46/100], Step [2/18], Loss: 24.1147
# Epoch [46/100], Step [4/18], Loss: 45.7318
# Epoch [46/100], Step [6/18], Loss: 39.9213
# Epoch [46/100], Step [8/18], Loss: 30.1390
# Epoch [46/100], Step [10/18], Loss: 40.9212
# Epoch [46/100], Step [12/18], Loss: 24.4289
# Epoch [46/100], Step [14/18], Loss: 39.3562
# Epoch [46/100], Step [16/18], Loss: 39.2718
# Epoch [46/100], Step [18/18], Loss: 37.5941
# Epoch [47/100], Step [2/18], Loss: 45.1583
# Epoch [47/100], Step [4/18], Loss: 33.5050
# Epoch [47/100], Step [6/18], Loss: 29.5167
# Epoch [47/100], Step [8/18], Loss: 47.3785
# Epoch [47/100], Step [10/18], Loss: 38.2415
# Epoch [47/100], Step [12/18], Loss: 30.3325
# Epoch [47/100], Step [14/18], Loss: 61.9170
# Epoch [47/100], Step [16/18], Loss: 44.6440
# Epoch [47/100], Step [18/18], Loss: 26.6622
# Epoch [48/100], Step [2/18], Loss: 23.8024
# Epoch [48/100], Step [4/18], Loss: 26.1447
# Epoch [48/100], Step [6/18], Loss: 33.8082
# Epoch [48/100], Step [8/18], Loss: 48.0169
# Epoch [48/100], Step [10/18], Loss: 31.6013
# Epoch [48/100], Step [12/18], Loss: 44.3494
# Epoch [48/100], Step [14/18], Loss: 38.3953
# Epoch [48/100], Step [16/18], Loss: 45.9954
# Epoch [48/100], Step [18/18], Loss: 42.0609
# Epoch [49/100], Step [2/18], Loss: 34.4608
# Epoch [49/100], Step [4/18], Loss: 54.6480
# Epoch [49/100], Step [6/18], Loss: 51.6886
# Epoch [49/100], Step [8/18], Loss: 29.9213
# Epoch [49/100], Step [10/18], Loss: 42.6910
# Epoch [49/100], Step [12/18], Loss: 49.3769
# Epoch [49/100], Step [14/18], Loss: 40.3966
# Epoch [49/100], Step [16/18], Loss: 56.7583
# Epoch [49/100], Step [18/18], Loss: 28.3952
# Epoch [50/100], Step [2/18], Loss: 47.1723
# Epoch [50/100], Step [4/18], Loss: 44.1907
# Epoch [50/100], Step [6/18], Loss: 43.0128
# Epoch [50/100], Step [8/18], Loss: 63.1437
# Epoch [50/100], Step [10/18], Loss: 28.5313
# Epoch [50/100], Step [12/18], Loss: 35.3549
# Epoch [50/100], Step [14/18], Loss: 35.5040
# Epoch [50/100], Step [16/18], Loss: 30.6301
# Epoch [50/100], Step [18/18], Loss: 34.2003
# Epoch [51/100], Step [2/18], Loss: 33.0552
# Epoch [51/100], Step [4/18], Loss: 43.9033
# Epoch [51/100], Step [6/18], Loss: 34.4878
# Epoch [51/100], Step [8/18], Loss: 23.7682
# Epoch [51/100], Step [10/18], Loss: 20.9041
# Epoch [51/100], Step [12/18], Loss: 32.3405
# Epoch [51/100], Step [14/18], Loss: 30.6193
# Epoch [51/100], Step [16/18], Loss: 21.8040
# Epoch [51/100], Step [18/18], Loss: 21.8589
# Epoch [52/100], Step [2/18], Loss: 30.9502
# Epoch [52/100], Step [4/18], Loss: 24.5160
# Epoch [52/100], Step [6/18], Loss: 31.1096
# Epoch [52/100], Step [8/18], Loss: 36.5706
# Epoch [52/100], Step [10/18], Loss: 38.4038
# Epoch [52/100], Step [12/18], Loss: 51.8235
# Epoch [52/100], Step [14/18], Loss: 21.9358
# Epoch [52/100], Step [16/18], Loss: 33.3200
# Epoch [52/100], Step [18/18], Loss: 49.2019
# Epoch [53/100], Step [2/18], Loss: 30.9203
# Epoch [53/100], Step [4/18], Loss: 21.9617
# Epoch [53/100], Step [6/18], Loss: 33.7922
# Epoch [53/100], Step [8/18], Loss: 22.5480
# Epoch [53/100], Step [10/18], Loss: 34.4398
# Epoch [53/100], Step [12/18], Loss: 30.9105
# Epoch [53/100], Step [14/18], Loss: 30.0710
# Epoch [53/100], Step [16/18], Loss: 30.3955
# Epoch [53/100], Step [18/18], Loss: 14.4257
# Epoch [54/100], Step [2/18], Loss: 26.5972
# Epoch [54/100], Step [4/18], Loss: 26.7882
# Epoch [54/100], Step [6/18], Loss: 35.1736
# Epoch [54/100], Step [8/18], Loss: 30.1517
# Epoch [54/100], Step [10/18], Loss: 35.0045
# Epoch [54/100], Step [12/18], Loss: 26.5707
# Epoch [54/100], Step [14/18], Loss: 31.0800
# Epoch [54/100], Step [16/18], Loss: 30.3140
# Epoch [54/100], Step [18/18], Loss: 32.6977
# Epoch [55/100], Step [2/18], Loss: 31.6453
# Epoch [55/100], Step [4/18], Loss: 25.0129
# Epoch [55/100], Step [6/18], Loss: 32.0584
# Epoch [55/100], Step [8/18], Loss: 20.3485
# Epoch [55/100], Step [10/18], Loss: 32.0864
# Epoch [55/100], Step [12/18], Loss: 26.3425
# Epoch [55/100], Step [14/18], Loss: 32.5678
# Epoch [55/100], Step [16/18], Loss: 24.9867
# Epoch [55/100], Step [18/18], Loss: 33.7988
# Epoch [56/100], Step [2/18], Loss: 26.3024
# Epoch [56/100], Step [4/18], Loss: 24.1652
# Epoch [56/100], Step [6/18], Loss: 41.0841
# Epoch [56/100], Step [8/18], Loss: 27.8926
# Epoch [56/100], Step [10/18], Loss: 44.8831
# Epoch [56/100], Step [12/18], Loss: 32.1663
# Epoch [56/100], Step [14/18], Loss: 31.1749
# Epoch [56/100], Step [16/18], Loss: 23.8924
# Epoch [56/100], Step [18/18], Loss: 27.0679
# Epoch [57/100], Step [2/18], Loss: 19.6462
# Epoch [57/100], Step [4/18], Loss: 21.6357
# Epoch [57/100], Step [6/18], Loss: 23.0000
# Epoch [57/100], Step [8/18], Loss: 25.8454
# Epoch [57/100], Step [10/18], Loss: 30.2765
# Epoch [57/100], Step [12/18], Loss: 30.4790
# Epoch [57/100], Step [14/18], Loss: 41.1465
# Epoch [57/100], Step [16/18], Loss: 41.3138
# Epoch [57/100], Step [18/18], Loss: 26.2313
# Epoch [58/100], Step [2/18], Loss: 22.4161
# Epoch [58/100], Step [4/18], Loss: 30.1681
# Epoch [58/100], Step [6/18], Loss: 36.9830
# Epoch [58/100], Step [8/18], Loss: 26.8959
# Epoch [58/100], Step [10/18], Loss: 35.5771
# Epoch [58/100], Step [12/18], Loss: 20.3137
# Epoch [58/100], Step [14/18], Loss: 30.0627
# Epoch [58/100], Step [16/18], Loss: 38.0063
# Epoch [58/100], Step [18/18], Loss: 44.6391
# Epoch [59/100], Step [2/18], Loss: 34.3096
# Epoch [59/100], Step [4/18], Loss: 29.5669
# Epoch [59/100], Step [6/18], Loss: 37.7553
# Epoch [59/100], Step [8/18], Loss: 36.6553
# Epoch [59/100], Step [10/18], Loss: 34.7610
# Epoch [59/100], Step [12/18], Loss: 27.9508
# Epoch [59/100], Step [14/18], Loss: 32.0191
# Epoch [59/100], Step [16/18], Loss: 46.8364
# Epoch [59/100], Step [18/18], Loss: 38.5085
# Epoch [60/100], Step [2/18], Loss: 28.3336
# Epoch [60/100], Step [4/18], Loss: 32.4177
# Epoch [60/100], Step [6/18], Loss: 22.2488
# Epoch [60/100], Step [8/18], Loss: 35.3319
# Epoch [60/100], Step [10/18], Loss: 32.2824
# Epoch [60/100], Step [12/18], Loss: 32.3300
# Epoch [60/100], Step [14/18], Loss: 35.1974
# Epoch [60/100], Step [16/18], Loss: 37.6385
# Epoch [60/100], Step [18/18], Loss: 51.7504
# Epoch [61/100], Step [2/18], Loss: 37.8529
# Epoch [61/100], Step [4/18], Loss: 27.4866
# Epoch [61/100], Step [6/18], Loss: 33.2628
# Epoch [61/100], Step [8/18], Loss: 38.6280
# Epoch [61/100], Step [10/18], Loss: 29.4386
# Epoch [61/100], Step [12/18], Loss: 41.3938
# Epoch [61/100], Step [14/18], Loss: 34.2165
# Epoch [61/100], Step [16/18], Loss: 36.9834
# Epoch [61/100], Step [18/18], Loss: 26.5081
# Epoch [62/100], Step [2/18], Loss: 31.1017
# Epoch [62/100], Step [4/18], Loss: 48.5420
# Epoch [62/100], Step [6/18], Loss: 32.9094
# Epoch [62/100], Step [8/18], Loss: 26.4604
# Epoch [62/100], Step [10/18], Loss: 38.7682
# Epoch [62/100], Step [12/18], Loss: 36.6487
# Epoch [62/100], Step [14/18], Loss: 33.8781
# Epoch [62/100], Step [16/18], Loss: 21.7343
# Epoch [62/100], Step [18/18], Loss: 38.6995
# Epoch [63/100], Step [2/18], Loss: 37.5304
# Epoch [63/100], Step [4/18], Loss: 25.2581
# Epoch [63/100], Step [6/18], Loss: 21.1857
# Epoch [63/100], Step [8/18], Loss: 58.1587
# Epoch [63/100], Step [10/18], Loss: 66.9209
# Epoch [63/100], Step [12/18], Loss: 53.2551
# Epoch [63/100], Step [14/18], Loss: 46.4489
# Epoch [63/100], Step [16/18], Loss: 28.4452
# Epoch [63/100], Step [18/18], Loss: 43.0979
# Epoch [64/100], Step [2/18], Loss: 31.4994
# Epoch [64/100], Step [4/18], Loss: 41.2908
# Epoch [64/100], Step [6/18], Loss: 33.9170
# Epoch [64/100], Step [8/18], Loss: 21.3777
# Epoch [64/100], Step [10/18], Loss: 38.1455
# Epoch [64/100], Step [12/18], Loss: 25.5836
# Epoch [64/100], Step [14/18], Loss: 37.0298
# Epoch [64/100], Step [16/18], Loss: 29.3306
# Epoch [64/100], Step [18/18], Loss: 32.7950
# Epoch [65/100], Step [2/18], Loss: 21.4009
# Epoch [65/100], Step [4/18], Loss: 45.0156
# Epoch [65/100], Step [6/18], Loss: 29.2912
# Epoch [65/100], Step [8/18], Loss: 21.6998
# Epoch [65/100], Step [10/18], Loss: 38.1157
# Epoch [65/100], Step [12/18], Loss: 43.2639
# Epoch [65/100], Step [14/18], Loss: 26.9516
# Epoch [65/100], Step [16/18], Loss: 36.6549
# Epoch [65/100], Step [18/18], Loss: 30.4429
# Epoch [66/100], Step [2/18], Loss: 27.5934
# Epoch [66/100], Step [4/18], Loss: 33.7384
# Epoch [66/100], Step [6/18], Loss: 26.7481
# Epoch [66/100], Step [8/18], Loss: 16.2014
# Epoch [66/100], Step [10/18], Loss: 25.0963
# Epoch [66/100], Step [12/18], Loss: 26.2994
# Epoch [66/100], Step [14/18], Loss: 27.8129
# Epoch [66/100], Step [16/18], Loss: 21.6786
# Epoch [66/100], Step [18/18], Loss: 29.5230
# Epoch [67/100], Step [2/18], Loss: 35.1467
# Epoch [67/100], Step [4/18], Loss: 31.6032
# Epoch [67/100], Step [6/18], Loss: 19.5916
# Epoch [67/100], Step [8/18], Loss: 25.7433
# Epoch [67/100], Step [10/18], Loss: 28.7736
# Epoch [67/100], Step [12/18], Loss: 28.0604
# Epoch [67/100], Step [14/18], Loss: 30.8875
# Epoch [67/100], Step [16/18], Loss: 27.4340
# Epoch [67/100], Step [18/18], Loss: 20.3711
# Epoch [68/100], Step [2/18], Loss: 20.9931
# Epoch [68/100], Step [4/18], Loss: 33.9123
# Epoch [68/100], Step [6/18], Loss: 35.9764
# Epoch [68/100], Step [8/18], Loss: 20.0535
# Epoch [68/100], Step [10/18], Loss: 26.1349
# Epoch [68/100], Step [12/18], Loss: 18.7555
# Epoch [68/100], Step [14/18], Loss: 18.4927
# Epoch [68/100], Step [16/18], Loss: 32.9481
# Epoch [68/100], Step [18/18], Loss: 35.6779
# Epoch [69/100], Step [2/18], Loss: 37.8437
# Epoch [69/100], Step [4/18], Loss: 28.7831
# Epoch [69/100], Step [6/18], Loss: 32.1080
# Epoch [69/100], Step [8/18], Loss: 21.6190
# Epoch [69/100], Step [10/18], Loss: 35.7688
# Epoch [69/100], Step [12/18], Loss: 43.4728
# Epoch [69/100], Step [14/18], Loss: 34.9356
# Epoch [69/100], Step [16/18], Loss: 33.1072
# Epoch [69/100], Step [18/18], Loss: 40.8391
# Epoch [70/100], Step [2/18], Loss: 32.4615
# Epoch [70/100], Step [4/18], Loss: 34.4060
# Epoch [70/100], Step [6/18], Loss: 39.2350
# Epoch [70/100], Step [8/18], Loss: 29.0974
# Epoch [70/100], Step [10/18], Loss: 46.4250
# Epoch [70/100], Step [12/18], Loss: 47.2208
# Epoch [70/100], Step [14/18], Loss: 35.0690
# Epoch [70/100], Step [16/18], Loss: 28.0162
# Epoch [70/100], Step [18/18], Loss: 35.6192
# Epoch [71/100], Step [2/18], Loss: 29.0462
# Epoch [71/100], Step [4/18], Loss: 28.5955
# Epoch [71/100], Step [6/18], Loss: 23.3313
# Epoch [71/100], Step [8/18], Loss: 50.7577
# Epoch [71/100], Step [10/18], Loss: 52.9428
# Epoch [71/100], Step [12/18], Loss: 27.4598
# Epoch [71/100], Step [14/18], Loss: 32.7608
# Epoch [71/100], Step [16/18], Loss: 46.7237
# Epoch [71/100], Step [18/18], Loss: 29.8077
# Epoch [72/100], Step [2/18], Loss: 41.2941
# Epoch [72/100], Step [4/18], Loss: 38.7150
# Epoch [72/100], Step [6/18], Loss: 29.4176
# Epoch [72/100], Step [8/18], Loss: 46.5045
# Epoch [72/100], Step [10/18], Loss: 29.3536
# Epoch [72/100], Step [12/18], Loss: 21.6006
# Epoch [72/100], Step [14/18], Loss: 27.8404
# Epoch [72/100], Step [16/18], Loss: 31.6876
# Epoch [72/100], Step [18/18], Loss: 42.8586
# Epoch [73/100], Step [2/18], Loss: 25.1887
# Epoch [73/100], Step [4/18], Loss: 22.7613
# Epoch [73/100], Step [6/18], Loss: 37.5146
# Epoch [73/100], Step [8/18], Loss: 21.7091
# Epoch [73/100], Step [10/18], Loss: 36.1631
# Epoch [73/100], Step [12/18], Loss: 32.1973
# Epoch [73/100], Step [14/18], Loss: 27.6072
# Epoch [73/100], Step [16/18], Loss: 31.4771
# Epoch [73/100], Step [18/18], Loss: 42.1207
# Epoch [74/100], Step [2/18], Loss: 42.3486
# Epoch [74/100], Step [4/18], Loss: 28.9480
# Epoch [74/100], Step [6/18], Loss: 27.9875
# Epoch [74/100], Step [8/18], Loss: 28.5497
# Epoch [74/100], Step [10/18], Loss: 18.4106
# Epoch [74/100], Step [12/18], Loss: 26.3636
# Epoch [74/100], Step [14/18], Loss: 32.9886
# Epoch [74/100], Step [16/18], Loss: 25.6491
# Epoch [74/100], Step [18/18], Loss: 29.1906
# Epoch [75/100], Step [2/18], Loss: 27.4564
# Epoch [75/100], Step [4/18], Loss: 22.8726
# Epoch [75/100], Step [6/18], Loss: 26.6879
# Epoch [75/100], Step [8/18], Loss: 19.1665
# Epoch [75/100], Step [10/18], Loss: 54.1802
# Epoch [75/100], Step [12/18], Loss: 32.2566
# Epoch [75/100], Step [14/18], Loss: 21.1902
# Epoch [75/100], Step [16/18], Loss: 19.9282
# Epoch [75/100], Step [18/18], Loss: 51.6481
# Epoch [76/100], Step [2/18], Loss: 34.9365
# Epoch [76/100], Step [4/18], Loss: 30.9743
# Epoch [76/100], Step [6/18], Loss: 24.0533
# Epoch [76/100], Step [8/18], Loss: 21.2791
# Epoch [76/100], Step [10/18], Loss: 33.2523
# Epoch [76/100], Step [12/18], Loss: 18.7216
# Epoch [76/100], Step [14/18], Loss: 22.4486
# Epoch [76/100], Step [16/18], Loss: 21.6530
# Epoch [76/100], Step [18/18], Loss: 16.6933
# Epoch [77/100], Step [2/18], Loss: 25.6077
# Epoch [77/100], Step [4/18], Loss: 22.1060
# Epoch [77/100], Step [6/18], Loss: 20.5992
# Epoch [77/100], Step [8/18], Loss: 36.4003
# Epoch [77/100], Step [10/18], Loss: 24.9008
# Epoch [77/100], Step [12/18], Loss: 27.3912
# Epoch [77/100], Step [14/18], Loss: 20.1152
# Epoch [77/100], Step [16/18], Loss: 29.2461
# Epoch [77/100], Step [18/18], Loss: 25.0713
# Epoch [78/100], Step [2/18], Loss: 17.0692
# Epoch [78/100], Step [4/18], Loss: 27.0926
# Epoch [78/100], Step [6/18], Loss: 24.3752
# Epoch [78/100], Step [8/18], Loss: 24.4193
# Epoch [78/100], Step [10/18], Loss: 25.4107
# Epoch [78/100], Step [12/18], Loss: 14.8741
# Epoch [78/100], Step [14/18], Loss: 25.6248
# Epoch [78/100], Step [16/18], Loss: 20.0945
# Epoch [78/100], Step [18/18], Loss: 19.3332
# Epoch [79/100], Step [2/18], Loss: 26.3988
# Epoch [79/100], Step [4/18], Loss: 20.3511
# Epoch [79/100], Step [6/18], Loss: 15.8959
# Epoch [79/100], Step [8/18], Loss: 32.9810
# Epoch [79/100], Step [10/18], Loss: 19.5367
# Epoch [79/100], Step [12/18], Loss: 29.8070
# Epoch [79/100], Step [14/18], Loss: 21.2475
# Epoch [79/100], Step [16/18], Loss: 15.7847
# Epoch [79/100], Step [18/18], Loss: 37.8603
# Epoch [80/100], Step [2/18], Loss: 21.9868
# Epoch [80/100], Step [4/18], Loss: 19.2533
# Epoch [80/100], Step [6/18], Loss: 18.6448
# Epoch [80/100], Step [8/18], Loss: 23.4352
# Epoch [80/100], Step [10/18], Loss: 25.3922
# Epoch [80/100], Step [12/18], Loss: 27.4191
# Epoch [80/100], Step [14/18], Loss: 24.3600
# Epoch [80/100], Step [16/18], Loss: 24.2634
# Epoch [80/100], Step [18/18], Loss: 15.3395
# Epoch [81/100], Step [2/18], Loss: 28.5264
# Epoch [81/100], Step [4/18], Loss: 24.9359
# Epoch [81/100], Step [6/18], Loss: 24.8231
# Epoch [81/100], Step [8/18], Loss: 33.1911
# Epoch [81/100], Step [10/18], Loss: 30.4349
# Epoch [81/100], Step [12/18], Loss: 32.1716
# Epoch [81/100], Step [14/18], Loss: 16.8824
# Epoch [81/100], Step [16/18], Loss: 16.1468
# Epoch [81/100], Step [18/18], Loss: 26.2936
# Epoch [82/100], Step [2/18], Loss: 35.0422
# Epoch [82/100], Step [4/18], Loss: 29.1919
# Epoch [82/100], Step [6/18], Loss: 30.0218
# Epoch [82/100], Step [8/18], Loss: 13.6466
# Epoch [82/100], Step [10/18], Loss: 25.6306
# Epoch [82/100], Step [12/18], Loss: 20.2252
# Epoch [82/100], Step [14/18], Loss: 26.0395
# Epoch [82/100], Step [16/18], Loss: 23.7912
# Epoch [82/100], Step [18/18], Loss: 25.2554
# Epoch [83/100], Step [2/18], Loss: 22.9981
# Epoch [83/100], Step [4/18], Loss: 25.0899
# Epoch [83/100], Step [6/18], Loss: 34.9512
# Epoch [83/100], Step [8/18], Loss: 19.1187
# Epoch [83/100], Step [10/18], Loss: 32.7897
# Epoch [83/100], Step [12/18], Loss: 33.2867
# Epoch [83/100], Step [14/18], Loss: 22.0781
# Epoch [83/100], Step [16/18], Loss: 27.7379
# Epoch [83/100], Step [18/18], Loss: 35.6613
# Epoch [84/100], Step [2/18], Loss: 30.2093
# Epoch [84/100], Step [4/18], Loss: 27.5833
# Epoch [84/100], Step [6/18], Loss: 30.4425
# Epoch [84/100], Step [8/18], Loss: 34.8466
# Epoch [84/100], Step [10/18], Loss: 31.4834
# Epoch [84/100], Step [12/18], Loss: 41.0681
# Epoch [84/100], Step [14/18], Loss: 35.1865
# Epoch [84/100], Step [16/18], Loss: 40.3546
# Epoch [84/100], Step [18/18], Loss: 40.8353
# Epoch [85/100], Step [2/18], Loss: 24.8734
# Epoch [85/100], Step [4/18], Loss: 43.2954
# Epoch [85/100], Step [6/18], Loss: 42.4582
# Epoch [85/100], Step [8/18], Loss: 21.7972
# Epoch [85/100], Step [10/18], Loss: 36.5362
# Epoch [85/100], Step [12/18], Loss: 39.0452
# Epoch [85/100], Step [14/18], Loss: 21.8570
# Epoch [85/100], Step [16/18], Loss: 39.3073
# Epoch [85/100], Step [18/18], Loss: 54.2045
# Epoch [86/100], Step [2/18], Loss: 29.2993
# Epoch [86/100], Step [4/18], Loss: 32.9533
# Epoch [86/100], Step [6/18], Loss: 44.7542
# Epoch [86/100], Step [8/18], Loss: 27.6491
# Epoch [86/100], Step [10/18], Loss: 29.3317
# Epoch [86/100], Step [12/18], Loss: 41.1649
# Epoch [86/100], Step [14/18], Loss: 30.7590
# Epoch [86/100], Step [16/18], Loss: 30.2526
# Epoch [86/100], Step [18/18], Loss: 31.2265
# Epoch [87/100], Step [2/18], Loss: 22.8057
# Epoch [87/100], Step [4/18], Loss: 40.9127
# Epoch [87/100], Step [6/18], Loss: 43.0130
# Epoch [87/100], Step [8/18], Loss: 43.5014
# Epoch [87/100], Step [10/18], Loss: 26.1092
# Epoch [87/100], Step [12/18], Loss: 29.7171
# Epoch [87/100], Step [14/18], Loss: 29.5673
# Epoch [87/100], Step [16/18], Loss: 39.4800
# Epoch [87/100], Step [18/18], Loss: 29.6280
# Epoch [88/100], Step [2/18], Loss: 31.5768
# Epoch [88/100], Step [4/18], Loss: 44.3595
# Epoch [88/100], Step [6/18], Loss: 33.0926
# Epoch [88/100], Step [8/18], Loss: 21.5788
# Epoch [88/100], Step [10/18], Loss: 31.3539
# Epoch [88/100], Step [12/18], Loss: 38.1671
# Epoch [88/100], Step [14/18], Loss: 23.8138
# Epoch [88/100], Step [16/18], Loss: 19.7347
# Epoch [88/100], Step [18/18], Loss: 21.9219
# Epoch [89/100], Step [2/18], Loss: 21.4216
# Epoch [89/100], Step [4/18], Loss: 31.4542
# Epoch [89/100], Step [6/18], Loss: 23.6335
# Epoch [89/100], Step [8/18], Loss: 32.4820
# Epoch [89/100], Step [10/18], Loss: 26.8403
# Epoch [89/100], Step [12/18], Loss: 29.0307
# Epoch [89/100], Step [14/18], Loss: 21.5896
# Epoch [89/100], Step [16/18], Loss: 28.7498
# Epoch [89/100], Step [18/18], Loss: 22.2134
# Epoch [90/100], Step [2/18], Loss: 29.7906
# Epoch [90/100], Step [4/18], Loss: 23.9456
# Epoch [90/100], Step [6/18], Loss: 21.6858
# Epoch [90/100], Step [8/18], Loss: 19.0985
# Epoch [90/100], Step [10/18], Loss: 30.9001
# Epoch [90/100], Step [12/18], Loss: 35.0304
# Epoch [90/100], Step [14/18], Loss: 31.9621
# Epoch [90/100], Step [16/18], Loss: 20.3206
# Epoch [90/100], Step [18/18], Loss: 26.4498
# Epoch [91/100], Step [2/18], Loss: 27.9705
# Epoch [91/100], Step [4/18], Loss: 17.4259
# Epoch [91/100], Step [6/18], Loss: 19.3651
# Epoch [91/100], Step [8/18], Loss: 18.3192
# Epoch [91/100], Step [10/18], Loss: 27.6403
# Epoch [91/100], Step [12/18], Loss: 26.8499
# Epoch [91/100], Step [14/18], Loss: 25.3769
# Epoch [91/100], Step [16/18], Loss: 19.0432
# Epoch [91/100], Step [18/18], Loss: 34.1615
# Epoch [92/100], Step [2/18], Loss: 22.2475
# Epoch [92/100], Step [4/18], Loss: 22.6490
# Epoch [92/100], Step [6/18], Loss: 16.4353
# Epoch [92/100], Step [8/18], Loss: 16.2287
# Epoch [92/100], Step [10/18], Loss: 20.9036
# Epoch [92/100], Step [12/18], Loss: 20.6501
# Epoch [92/100], Step [14/18], Loss: 28.8013
# Epoch [92/100], Step [16/18], Loss: 19.0313
# Epoch [92/100], Step [18/18], Loss: 25.2608
# Epoch [93/100], Step [2/18], Loss: 24.5990
# Epoch [93/100], Step [4/18], Loss: 16.2367
# Epoch [93/100], Step [6/18], Loss: 25.2941
# Epoch [93/100], Step [8/18], Loss: 14.2796
# Epoch [93/100], Step [10/18], Loss: 31.5013
# Epoch [93/100], Step [12/18], Loss: 29.3584
# Epoch [93/100], Step [14/18], Loss: 21.0355
# Epoch [93/100], Step [16/18], Loss: 20.0628
# Epoch [93/100], Step [18/18], Loss: 21.8574
# Epoch [94/100], Step [2/18], Loss: 15.6598
# Epoch [94/100], Step [4/18], Loss: 20.8936
# Epoch [94/100], Step [6/18], Loss: 22.7341
# Epoch [94/100], Step [8/18], Loss: 18.9594
# Epoch [94/100], Step [10/18], Loss: 21.5669
# Epoch [94/100], Step [12/18], Loss: 20.7588
# Epoch [94/100], Step [14/18], Loss: 28.8228
# Epoch [94/100], Step [16/18], Loss: 25.6202
# Epoch [94/100], Step [18/18], Loss: 27.5462
# Epoch [95/100], Step [2/18], Loss: 19.1206
# Epoch [95/100], Step [4/18], Loss: 16.1217
# Epoch [95/100], Step [6/18], Loss: 21.0360
# Epoch [95/100], Step [8/18], Loss: 19.5104
# Epoch [95/100], Step [10/18], Loss: 24.9665
# Epoch [95/100], Step [12/18], Loss: 18.4268
# Epoch [95/100], Step [14/18], Loss: 19.4717
# Epoch [95/100], Step [16/18], Loss: 14.7625
# Epoch [95/100], Step [18/18], Loss: 14.8955
# Epoch [96/100], Step [2/18], Loss: 25.8742
# Epoch [96/100], Step [4/18], Loss: 19.8529
# Epoch [96/100], Step [6/18], Loss: 24.1740
# Epoch [96/100], Step [8/18], Loss: 23.7612
# Epoch [96/100], Step [10/18], Loss: 21.1480
# Epoch [96/100], Step [12/18], Loss: 18.0828
# Epoch [96/100], Step [14/18], Loss: 15.3661
# Epoch [96/100], Step [16/18], Loss: 12.9309
# Epoch [96/100], Step [18/18], Loss: 14.1544
# Epoch [97/100], Step [2/18], Loss: 27.0325
# Epoch [97/100], Step [4/18], Loss: 21.2181
# Epoch [97/100], Step [6/18], Loss: 18.8787
# Epoch [97/100], Step [8/18], Loss: 15.1775
# Epoch [97/100], Step [10/18], Loss: 15.8071
# Epoch [97/100], Step [12/18], Loss: 19.1723
# Epoch [97/100], Step [14/18], Loss: 19.2754
# Epoch [97/100], Step [16/18], Loss: 23.7087
# Epoch [97/100], Step [18/18], Loss: 9.1532
# Epoch [98/100], Step [2/18], Loss: 14.2760
# Epoch [98/100], Step [4/18], Loss: 17.7035
# Epoch [98/100], Step [6/18], Loss: 14.5103
# Epoch [98/100], Step [8/18], Loss: 14.0968
# Epoch [98/100], Step [10/18], Loss: 16.0164
# Epoch [98/100], Step [12/18], Loss: 16.3728
# Epoch [98/100], Step [14/18], Loss: 16.7994
# Epoch [98/100], Step [16/18], Loss: 12.8780
# Epoch [98/100], Step [18/18], Loss: 19.4383
# Epoch [99/100], Step [2/18], Loss: 14.8235
# Epoch [99/100], Step [4/18], Loss: 16.9972
# Epoch [99/100], Step [6/18], Loss: 15.1001
# Epoch [99/100], Step [8/18], Loss: 13.3324
# Epoch [99/100], Step [10/18], Loss: 17.1970
# Epoch [99/100], Step [12/18], Loss: 17.1740
# Epoch [99/100], Step [14/18], Loss: 34.3214
# Epoch [99/100], Step [16/18], Loss: 20.1067
# Epoch [99/100], Step [18/18], Loss: 15.8233
# Epoch [100/100], Step [2/18], Loss: 22.1531
# Epoch [100/100], Step [4/18], Loss: 14.1058
# Epoch [100/100], Step [6/18], Loss: 22.5884
# Epoch [100/100], Step [8/18], Loss: 16.9875
# Epoch [100/100], Step [10/18], Loss: 16.5310
# Epoch [100/100], Step [12/18], Loss: 17.9743
# Epoch [100/100], Step [14/18], Loss: 23.2205
# Epoch [100/100], Step [16/18], Loss: 16.4494
# Epoch [100/100], Step [18/18], Loss: 20.4671

# %%
model.eval()
predicted_joints = list()
with torch.no_grad():
    for sample in validation_loader:
        prediction = model(sample["image"].to(device).float())
        for i, image_name in enumerate(sample["image_name"]):
          predicted_joints.append((image_name, prediction[i, :]))

# %%
show_joints(predicted_joints[144][0], predicted_joints[144][1].cpu().numpy().reshape(21, 2))

# %%
torch.save(model.state_dict(), 'model400epoch.ckpt')

# %% [markdown]
# <h2><b>Original Photo Experiment</b></h2>

# %%
image = Image.open("/content/drive/My Drive/el2.jpg").resize((400, 400))

# %%
image_tensor = torch.from_numpy(np.asarray(image)).permute(2, 0, 1)

# %%
original_sample = {"image_name": "original", "image": torch.unsqueeze(image_tensor, 0)}

# %%
model.eval()
preds = None
with torch.no_grad():
      preds = model(original_sample["image"].to(device).float())

# %%
plt.imshow(image)
landmarks = preds.cpu().numpy().reshape(21, 2)
plt.scatter(landmarks[:, 0], landmarks[:, 1], s=10, marker='.', c='r')
plt.pause(0.001)

# %% [markdown]
# I mean, I can't say it works well outside the dataset.
